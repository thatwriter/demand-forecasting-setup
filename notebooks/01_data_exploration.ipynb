# %%
# %%
# 01_data_exploration.ipynb
# Propósito: Validar que el ambiente está correctamente configurado
# Autores: 
# Jesus Edgar Jaramillo Armenta Lic. Ciencia de datos para Negocios
# Edgar Armando Picasso Villanueva Lic. Ciencia de datos para Negocios
import sys
print("✅ Intérprete de Python en uso:")
print(sys.executable)
print("\n✅ Paquetes instalados en este entorno:")
# !{sys.executable} -m pip list | findstr /i "pandas scikit-learn matplotlib jupyter"

# 1. Importar librerías requeridas
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

print("✅ Librerías importadas correctamente")

# %%
# 2. Cargar un dataset de ejemplo (Iris es pequeño y viene con scikit-learn)
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

print("✅ Dataset cargado en DataFrame")

# %%
# 3. Exploración básica: primeras filas y estadísticas descriptivas
print("Primeras 5 filas del dataset:")
display(df.head())

print("\nEstadísticas descriptivas:")
display(df.describe())

# %%
# 4. Visualización simple: histograma de una característica
plt.figure(figsize=(8, 4))
plt.hist(df['sepal length (cm)'], bins=15, color='skyblue', edgecolor='black')
plt.title('Distribución de la longitud del sépalo')
plt.xlabel('Longitud (cm)')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

print("✅ Gráfico generado con matplotlib")
# Out:
# ✅ Intérprete de Python en uso:
# c:\demand-forecasting-setup\env_demand_forecasting\Scripts\python.exe
#
# ✅ Paquetes instalados en este entorno:
# jupyter_client          8.6.3
# jupyter_core            5.9.1
# matplotlib              3.10.7
# matplotlib-inline       0.2.1
# pandas                  2.3.3
# scikit-learn            1.7.2
# ✅ Librerías importadas correctamente
# ✅ Dataset cargado en DataFrame
# Primeras 5 filas del dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ...
